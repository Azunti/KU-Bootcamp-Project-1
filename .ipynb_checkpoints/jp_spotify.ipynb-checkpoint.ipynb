# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

#hot_100_load = Path("Data/hot_100.csv")
bb_500 = Path('Data/2021_list_raw.csv')

#hot_100_data = pd.read_csv(hot_100_load)
bb_500_df = pd.read_csv(bb_500)

#remove songid column
bb_500_df = bb_500_df.drop(columns=['songid'] + ['Edition'])

# remove and blanks
bb_500_df = bb_500_df.dropna(subset=['Released'] + ['Song'] + ['Artist'] + ['Rank'])

#remove years 2018 to 2021
filtered_bb_500_df = bb_500_df[(bb_500_df['Released'] >= 1958) & (bb_500_df['Released'] < 2025)]

#Top 100 from the filtered list ( some values were missing adjusted to show top 100 row, as some were over.
filtered_bb_500_df = filtered_bb_500_df[:96]


filtered_bb_500_df.value_counts()
# Out:
# Rank  Artist              Song                           Released
# 1     Aretha Franklin     Respect                        1967        1
# 2     Public Enemy        Fight the Power                1989        1
# 73    Beyoncé             Formation                      2016        1
# 72    The Beatles         Yesterday                      1965        1
# 71    Tracy Chapman       Fast Car                       1988        1
#                                                                     ..
# 31    The Rolling Stones  (I Can't Get No) Satisfaction  1965        1
# 30    Lorde               Royals                         2011        1
# 29    Dr. Dre             Nuthin' but a 'G' Thang        1992        1
# 28    Talking Heads       Once in a Lifetime             1980        1
# 100   Bob Dylan           Blowin' in the Wind            1963        1
# Name: count, Length: 96, dtype: int64

# %%
# Bin by decade 
bins = [1958, 1970, 1980, 1990, 2000, 2010, 2025]
labels = ['1960-1969', '1970-1979', '1980-1989', '1990-1999','2000-2009', '2010-2024']

filtered_bb_500_df['Decade'] =pd.cut(filtered_bb_500_df['Released'], bins=bins, labels=labels, right=False)

#filtered_bb_500_df['Decade'] = filtered_bb_500_df['Decade'].astype(str)
filtered_bb_500_df.to_csv("Data/clea_bb_500.csv", index=False, header=True)

print(filtered_bb_500_df.columns)
# Out:
# Index(['Rank', 'Artist', 'Song', 'Released', 'Decade'], dtype='object')

# %%
#song_counts = filtered_bb_500_df.groupby('Decade')
#song_counts.count()

# %%
song_count = filtered_bb_500_df.groupby('Decade').size().reset_index(name='Song Count')
song_count
# Out:
# C:\Users\WHPav\AppData\Local\Temp\ipykernel_7920\2064763990.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   song_count = filtered_bb_500_df.groupby('Decade').size().reset_index(name='Song Count')
#       Decade  Song Count
# 0  1960-1969          30
# 1  1970-1979          23
# 2  1980-1989          14
# 3  1990-1999           8
# 4  2000-2009          13
# 5  2010-2024           8

# %%
song_count_data = {'Decade': ['1960-1969', '1970-1979', '1980-1989', '1990-1999','2000-2009', '2010-2019'],
                   'Song Count': song_count['Song Count'].tolist()
                  }
decade_df = pd.DataFrame(song_count_data)

decade_df.plot(kind='line', x='Decade', y='Song Count', marker='o')
plt.title('Amount of songs in Top 100 per Decade')
plt.ylabel('Total Amount of Songs')
plt.xlabel('Decade')
plt.show()

# %%
x_values = filtered_bb_500_df['Released']
y_values = filtered_bb_500_df['Rank']
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values, marker='o')
plt.plot(x_values,regress_values, 'r-')
plt.annotate(line_eq,(0,5), fontsize=15, color='red',)
plt.title('Relationship between Release year and Rank')
plt.xlabel('Release Year')
plt.ylabel('Rank')

print(f'the r^2 value is:{rvalue}')
plt.show()
# Out:
# the r^2 value is:0.08792609243901252
