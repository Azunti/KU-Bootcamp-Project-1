# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import sys
from pprint import pprint
from collections import Counter

client_credentials_manager = SpotifyClientCredentials(client_id='3ef39dfa962c41cea5f23b2c82f5476f', client_secret='1a85a7e5c3824be5a4f34b8b82be84fc')
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

#NEED TO BRING IN CSV TO MAKE DATA VISUALIZATION WITH NEW DATAFRAMES FOR GENRE AND POPULARITY
#bb_500_path = Path('Data/clean_bb_500.csv')
#bb_500_path_api = pd.read_csv(bb_500_path)
#bb_500_path_api.head()

# %%
# importing raw csv
tocm_df = pd.read_csv(Path("Data/tocm_rank.csv"))
genre_df=tocm_df
genre_df["Artist ID"]=""
genre_df["Genres"]=""
genre_df["Popularity"]=""
#line below to limit results and can be deactivated once code is working
genre_df = genre_df.loc[(genre_df["time_on_chart"] >50) , :]
genre_df.head()
# Out:
#               song        performer                     song_id  \
# 0       Heat Waves    Glass Animals     Heat WavesGlass Animals
# 1  Blinding Lights       The Weeknd   Blinding LightsThe Weeknd
# 2      Radioactive  Imagine Dragons  RadioactiveImagine Dragons
# 3             Sail       AWOLNATION              SailAWOLNATION
# 4        I'm Yours       Jason Mraz         I'm YoursJason Mraz
#
#    time_on_chart chart_debut Artist ID Genres Popularity
# 0             91  2021-01-16
# 1             90  2019-12-14
# 2             87  2012-08-18
# 3             79  2011-09-03
# 4             76  2008-05-03

# %%
# Iterate over rows in the DataFrame
for index, row in genre_df.iterrows():
    artist = row["performer"]
    
    # Search for the artist on Spotify
    result = sp.search(q=artist, type='artist', limit=1)
    
    if result['artists']['items']:
        artist_info = result['artists']['items'][0]
        artist_id = artist_info['id']
        
        # Update the DataFrame with the artist ID
        genre_df.loc[index, "Artist ID"] = artist_id
        
        # Create the artist URI
        urn = f"spotify:artist:{artist_id}"
        #print(urn)
        
        # Fetch artist details
        artist_search = sp.artist(artist_id)
        
        # Update the DataFrame with the genre and popularity
        genres = artist_search.get('genres', [])
        genres = artist_search.get('genres', [])
        genre_df.at[index, "Genres"] = ', '.join(genres) if genres else "Unknown"
        
        popularity = artist_search.get('popularity', 0)
        genre_df.loc[index, "Popularity"] = popularity
        
        #Print the genre and popularity
        pprint(genres)
        print(f"Popularity: {popularity}")
    else:
        print(f"No results found for artist: {artist}")
        
# Display the updated DataFrame
genre_df.head()
# Out:
# ['gauze pop', 'indietronica', 'modern rock', 'pov: indie', 'shiver pop']
# Popularity: 78
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# Popularity: 94
# ['modern rock', 'pop', 'rock']
# Popularity: 88
# ['la indie', 'modern alternative rock', 'modern rock', 'rock', 'stomp pop']
# Popularity: 62
# ['acoustic pop', 'dance pop', 'neo mellow', 'pop']
# Popularity: 71
# ['pop', 'r&b', 'rap']
# Popularity: 89
# ['contemporary country', 'country', 'country dawn', 'country road']
# Popularity: 63
# ['piano rock', 'pop']
# Popularity: 85
# ['dance pop', 'pop', 'pop rap']
# Popularity: 67
# ['classic oklahoma country']
# Popularity: 91
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# Popularity: 94
# ['dance pop', 'pop', 'urban contemporary']
# Popularity: 77
# ['british soul', 'pop', 'pop soul', 'uk pop']
# Popularity: 86
# ['alaska indie',
#  'ectofolk',
#  'lilith',
#  'permanent wave',
#  'pop rock',
#  'singer-songwriter']
# Popularity: 57
# ['classic oklahoma country',
#  'contemporary country',
#  'country',
#  'country dawn',
#  'dance pop',
#  'pop']
# Popularity: 70
# ['contemporary country']
# Popularity: 91
# ['australian hip hop']
# Popularity: 83
# ['neo mellow', 'pop rock', 'post-grunge']
# Popularity: 64
# ['contemporary country']
# Popularity: 61
# ['folk-pop', 'modern rock', 'neo mellow', 'stomp and holler']
# Popularity: 79
# ['pop']
# Popularity: 84
# ['modern rock', 'pop', 'rock']
# Popularity: 88
# ['dfw rap', 'melodic rap', 'pop', 'rap']
# Popularity: 92
# ['tropical']
# Popularity: 58
# ['contemporary country']
# Popularity: 91
# ['contemporary country',
#  'country',
#  'country dawn',
#  'country pop',
#  'country road']
# Popularity: 66
# ['neo soul', 'pop', 'pop soul', 'urban contemporary']
# Popularity: 75
# ['bergen indie', 'electropop', 'nz pop']
# Popularity: 72
# ['adult standards', 'lounge', 'rockabilly']
# Popularity: 56
# ['neo mellow', 'piano rock', 'pop', 'pop rock']
# Popularity: 70
# ['pop', 'singer-songwriter pop', 'uk pop']
# Popularity: 87
# ['neo mellow', 'pop rock', 'post-grunge']
# Popularity: 61
# ['pop', 'singer-songwriter pop', 'uk pop']
# Popularity: 87
# ['afrobeats', 'nigerian pop']
# Popularity: 78
# ['alternative metal', 'nu metal', 'post-grunge', 'rock']
# Popularity: 72
# ['modern rock', 'rock']
# Popularity: 77
# []
# Popularity: 45
# ['contemporary country']
# Popularity: 91
# ['indietronica', 'metropopolis', 'pop', 'uk pop']
# Popularity: 80
# ['crunk', 'memphis hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
# Popularity: 73
# ['adult standards',
#  'brill building pop',
#  'folk rock',
#  'mellow gold',
#  'motown',
#  'rock-and-roll',
#  'rockabilly']
# Popularity: 63
# ['pop soul']
# Popularity: 76
# ['pop', 'singer-songwriter pop', 'uk pop']
# Popularity: 87
# ['contemporary country', 'country']
# Popularity: 87
# ['baroque pop', 'metropopolis', 'neo mellow']
# Popularity: 67
# ['pop', 'singer-songwriter pop', 'uk pop']
# Popularity: 87
# ['contemporary country', 'country', 'country dawn', 'country road']
# Popularity: 62
# ['ectofolk', 'lilith', 'new wave pop', 'pop rock']
# Popularity: 48
# ['dance pop', 'pop', 'pop rap']
# Popularity: 80
# ['contemporary country', 'country', 'country road']
# Popularity: 57
# ['contemporary country', 'modern country pop']
# Popularity: 76
# ['contemporary country']
# Popularity: 91
# ['pop rock']
# Popularity: 46
# ['new wave pop', 'sophisti-pop', 'trip hop']
# Popularity: 57
# ['pop']
# Popularity: 83
# ['dance pop', 'neo mellow', 'pop', 'pop rock']
# Popularity: 76
# ['neo mellow', 'pop rock', 'post-grunge']
# Popularity: 68
# ['pop', 'uk pop']
# Popularity: 79
# ['pop', 'uk pop']
# Popularity: 83
# ['neo mellow', 'pop rock', 'post-grunge']
# Popularity: 64
# ['pop']
# Popularity: 100
# ['contemporary country',
#  'country',
#  'country pop',
#  'country road',
#  'modern country rock']
# Popularity: 73
# ['dance pop', 'edm', 'pop', 'pop dance']
# Popularity: 81
# ['contemporary country', 'country', 'country dawn', 'country road']
# Popularity: 55
# ['dfw rap', 'melodic rap', 'pop', 'rap']
# Popularity: 92
# ['boy band',
#  'contemporary r&b',
#  'minneapolis sound',
#  'new jack swing',
#  'r&b',
#  'urban contemporary']
# Popularity: 55
# ['metropopolis', 'modern rock', 'pop']
# Popularity: 74
# ['dance pop', 'neo mellow', 'pop', 'pop rock']
# Popularity: 76
# ['pop', 'r&b', 'rap']
# Popularity: 89
# ['dance rock',
#  'modern alternative rock',
#  'modern rock',
#  'neo mellow',
#  'pop rock']
# Popularity: 71
# ['alternative metal', 'nu metal', 'post-grunge', 'rock']
# Popularity: 71
# ['contemporary country', 'country', 'country dawn', 'country road']
# Popularity: 62
# ['contemporary country']
# Popularity: 91
# ['boy band', 'dance pop', 'pop rock']
# Popularity: 65
# ['electropop', 'etherpop', 'indie poptimism', 'pop']
# Popularity: 81
# ['dance pop', 'pop']
# Popularity: 85
# ['new jersey rap', 'pop rap', 'rap', 'southern hip hop', 'trap']
# Popularity: 70
# ['modern rock', 'pop', 'pov: indie', 'rock']
# Popularity: 82
# ['classic texas country', 'contemporary country']
# Popularity: 70
# ['r&b', 'urban contemporary']
# Popularity: 79
# ['canadian pop', 'pop', 'viral pop']
# Popularity: 83
# ['canadian pop', 'pop']
# Popularity: 89
# ['pop']
# Popularity: 82
# ['dance pop', 'pop', 'uk pop']
# Popularity: 88
# ['pop']
# Popularity: 85
# ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 'rap', 'trap']
# Popularity: 84
# ['brostep', 'edm', 'pop', 'progressive electro house']
# Popularity: 83
# ['pop']
# Popularity: 77
# ['pop', 'uk pop']
# Popularity: 79
# ['dfw rap', 'melodic rap', 'pop', 'rap']
# Popularity: 92
# ['glam rock', 'mellow gold', 'piano rock', 'rock']
# Popularity: 83
# ['dance pop', 'pop']
# Popularity: 81
# ['dance pop', 'dancehall', 'pop', 'pop rap']
# Popularity: 81
# ['pop']
# Popularity: 82
# ['pop', 'talent show', 'uk pop']
# Popularity: 81
# ['hip hop', 'pittsburgh rap', 'pop rap', 'rap', 'southern hip hop', 'trap']
# Popularity: 81
# ['pop', 'singer-songwriter pop', 'uk pop']
# Popularity: 87
# ['rap', 'slap house']
# Popularity: 93
# ['alternative metal', 'alternative rock', 'pop rock', 'post-grunge']
# Popularity: 66
# ['melodic rap']
# Popularity: 71
# ['ohio hip hop', 'pop rap']
# Popularity: 79
#               song        performer                     song_id  \
# 0       Heat Waves    Glass Animals     Heat WavesGlass Animals
# 1  Blinding Lights       The Weeknd   Blinding LightsThe Weeknd
# 2      Radioactive  Imagine Dragons  RadioactiveImagine Dragons
# 3             Sail       AWOLNATION              SailAWOLNATION
# 4        I'm Yours       Jason Mraz         I'm YoursJason Mraz
#
#    time_on_chart chart_debut               Artist ID  \
# 0             91  2021-01-16  4yvcSjfu4PC0CYQyLy4wSq
# 1             90  2019-12-14  1Xyo4u8uXC1ZmMpatF05PJ
# 2             87  2012-08-18  53XhwfbYqKCa1cC15pYq2q
# 3             79  2011-09-03  4njdEjTnLfcGImKZu1iSrz
# 4             76  2008-05-03  4phGZZrJZRo4ElhRtViYdl
#
#                                               Genres Popularity
# 0  gauze pop, indietronica, modern rock, pov: ind...         78
# 1       canadian contemporary r&b, canadian pop, pop         94
# 2                             modern rock, pop, rock         88
# 3  la indie, modern alternative rock, modern rock...         62
# 4           acoustic pop, dance pop, neo mellow, pop         71

# %%
sorted_df = genre_df.sort_values(by='Popularity', ascending=False)
most_popular_song = sorted_df.iloc[0]['song']
most_popular_artist = sorted_df.iloc[0]['performer']
print(f'The most popular song based on Popularity score is {most_popular_song} by {most_popular_artist}.')
#sorted_df.head()
# Out:
# The most popular song based on Popularity score is Anti-Hero by Taylor Swift.

# %%
#count the total genres listed for each row
count_genre_df = pd.DataFrame(genre_df)

#split the genre into seperate entries 
genre_series = count_genre_df['Genres'].str.split(', ', expand=True).stack()

#new DF
genre_count_df = pd.DataFrame(genre_series, columns=['Genre'])

#Count the occurances
genre_count = genre_count_df['Genre'].value_counts()

#convert to new DF 
final_count_df = genre_count.reset_index()
final_count_df.columns = ['Genre', 'Count']

print(final_count_df)
# Out:
#                    Genre  Count
# 0                    pop     48
# 1   contemporary country     17
# 2               pop rock     13
# 3              dance pop     13
# 4                 uk pop     12
# ..                   ...    ...
# 91    brill building pop      1
# 92             folk rock      1
# 93                motown      1
# 94         rock-and-roll      1
# 95          ohio hip hop      1
#
# [96 rows x 2 columns]
