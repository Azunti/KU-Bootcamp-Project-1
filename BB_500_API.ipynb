# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import sys
from pprint import pprint
from collections import Counter

client_credentials_manager = SpotifyClientCredentials(client_id='3ef39dfa962c41cea5f23b2c82f5476f', client_secret='1a85a7e5c3824be5a4f34b8b82be84fc')
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

#NEED TO BRING IN CSV TO MAKE DATA VISUALIZATION WITH NEW DATAFRAMES FOR GENRE AND POPULARITY
bb_500_path = Path('Data/clean_bb_500.csv')
bb_500_path_api = pd.read_csv(bb_500_path)
bb_500_path_api.head()
# Out:
#    Rank           Artist                     Song  Released     Decade
# 0     1  Aretha Franklin                  Respect      1967  1960-1969
# 1     2     Public Enemy          Fight the Power      1989  1980-1989
# 2     3        Sam Cooke   A Change Is Gonna Come      1964  1960-1969
# 3     4        Bob Dylan     Like a Rolling Stone      1965  1960-1969
# 4     5          Nirvana  Smells Like Teen Spirit      1991  1990-1999

# %%
# importing raw csv
genre_500_df = bb_500_path_api
genre_500_df["Artist ID"] = ""
genre_500_df["Genres"] = ""
genre_500_df["Popularity"] = ""
#line below to limit results and can be deactivated once code is working
#genre_500_df = genre_500_df.loc[(genre_df["time_on_chart"] >50) , :]
genre_500_df.head()
# Out:
#    Rank           Artist                     Song  Released     Decade  \
# 0     1  Aretha Franklin                  Respect      1967  1960-1969
# 1     2     Public Enemy          Fight the Power      1989  1980-1989
# 2     3        Sam Cooke   A Change Is Gonna Come      1964  1960-1969
# 3     4        Bob Dylan     Like a Rolling Stone      1965  1960-1969
# 4     5          Nirvana  Smells Like Teen Spirit      1991  1990-1999
#
#   Artist ID Genres Popularity
# 0
# 1
# 2
# 3
# 4

# %%
# Iterate over rows in the DataFrame
for index, row in genre_500_df.iterrows():
    artist = row["Artist"]
    
    # Search for the artist on Spotify
    result = sp.search(q=artist, type='artist', limit=1)
    
    if result['artists']['items']:
        artist_info = result['artists']['items'][0]
        artist_id = artist_info['id']
        
        # Update the DataFrame with the artist ID
        genre_500_df.loc[index, "Artist ID"] = artist_id
        
        # Create the artist URI
        urn = f"spotify:artist:{artist_id}"
        print(urn)
        
        # Fetch artist details
        artist_search = sp.artist(artist_id)
        
        # Update the DataFrame with the genre and popularity
        genres_500 = artist_search.get('genres', [])
        genres_500 = artist_search.get('genres', [])
        genre_500_df.at[index, "Genres"] = ', '.join(genres_500) if genres_500 else "Unknown"
        
        popularity = artist_search.get('popularity', 0)
        genre_500_df.loc[index, "Popularity"] = popularity
        
        #Print the genre and popularity
        pprint(genres_500)
        print(f"Popularity: {popularity}")
    else:
        print(f"No results found for artist: {artist}")
        
# Display the updated DataFrame
genre_500_df.head()
# Out:
# spotify:artist:7nwUJBm0HE4ZxD3f5cy5ok
# ['classic soul',
#  'jazz blues',
#  'memphis soul',
#  'soul',
#  'southern soul',
#  'vocal jazz']
# Popularity: 72
# spotify:artist:6Mo9PoU6svvhgEum7wh2Nd
# ['conscious hip hop',
#  'east coast hip hop',
#  'golden age hip hop',
#  'hardcore hip hop',
#  'hip hop',
#  'old school hip hop',
#  'political hip hop']
# Popularity: 56
# spotify:artist:6hnWRPzGGKiapVX1UCdEAC
# ['classic soul', 'soul', 'vocal jazz']
# Popularity: 68
# spotify:artist:74ASZWbe4lXaubB36ztrGX
# ['classic rock',
#  'country rock',
#  'folk',
#  'folk rock',
#  'rock',
#  'roots rock',
#  'singer-songwriter']
# Popularity: 73
# spotify:artist:6olE6TJLqED3rqDCT0FyPh
# ['grunge', 'permanent wave', 'rock']
# Popularity: 82
# spotify:artist:3koiLjNrgRTNbOwViDipeA
# ['classic soul',
#  'motown',
#  'neo soul',
#  'northern soul',
#  'quiet storm',
#  'soul',
#  'vocal jazz']
# Popularity: 74
# spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# ['british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# Popularity: 85
# spotify:artist:2wIVse2owClT7go1WT98tk
# ['dance pop',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'pop rap',
#  'r&b',
#  'rap',
#  'urban contemporary',
#  'virginia hip hop']
# Popularity: 71
# spotify:artist:08GQAI4eElDnROBrJRGE0X
# ['album rock', 'classic rock', 'rock', 'soft rock', 'yacht rock']
# Popularity: 82
# spotify:artist:1G9G7WwrXka3Z1r7aIDjI7
# ['atl hip hop',
#  'dirty south rap',
#  'hip hop',
#  'old school atlanta hip hop',
#  'rap',
#  'southern hip hop']
# Popularity: 76
# spotify:artist:3oDbviiivRWhXwIE8hxkVV
# ['baroque pop',
#  'classic rock',
#  'folk rock',
#  'mellow gold',
#  'psychedelic rock',
#  'rock',
#  'singer-songwriter',
#  'sunshine pop']
# Popularity: 73
# spotify:artist:7guDJrEfX3qb6FEbdPA5qi
# ['motown', 'soul']
# Popularity: 75
# spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# ['album rock', 'british invasion', 'classic rock', 'rock']
# Popularity: 79
# spotify:artist:1SQRv42e4PjEYfPhS0Tk9E
# ['album rock',
#  'art rock',
#  'british invasion',
#  'classic rock',
#  'folk rock',
#  'glam rock',
#  'protopunk',
#  'psychedelic rock',
#  'rock',
#  'singer-songwriter']
# Popularity: 65
# spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# ['british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# Popularity: 85
# spotify:artist:3nFkdlSjzX9mRTtwJOzDYB
# ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap']
# Popularity: 83
# spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# ['classic rock', 'glam rock', 'rock']
# Popularity: 85
# spotify:artist:5a2EaR3hamoenG9rDuVn8j
# ['funk', 'funk rock', 'minneapolis sound', 'rock', 'synth funk']
# Popularity: 71
# spotify:artist:4x1nvY2FN8jxqAFA0DA02H
# ['classic rock', 'rock']
# Popularity: 69
# spotify:artist:6UE7nl9mha6s8z0wFQFIZ2
# ['dance pop',
#  'electropop',
#  'neo-synthpop',
#  'scandipop',
#  'swedish electropop',
#  'swedish pop']
# Popularity: 64
# spotify:artist:7CyeXFnOrfC1N6z4naIpgo
# ['brill building pop', 'classic girl group', 'motown', 'rock-and-roll']
# Popularity: 63
# spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy
# ['art rock', 'classic rock', 'glam rock', 'permanent wave', 'rock']
# Popularity: 77
# spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# ['british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# Popularity: 85
# spotify:artist:5K4W6rqBFWDnAN6FQUkS6x
# ['chicago rap', 'hip hop', 'rap']
# Popularity: 92
# spotify:artist:5hW4L92KnC6dX9t7tYM4Ve
# ['canadian singer-songwriter', 'folk', 'folk rock', 'singer-songwriter']
# Popularity: 61
# spotify:artist:3eqjTLE0HfPfh78zjh6TqT
# ['heartland rock', 'mellow gold', 'permanent wave', 'rock', 'singer-songwriter']
# Popularity: 78
# spotify:artist:2x9SpqnPi8rlE9pjHBwmSC
# ['alternative rock',
#  'art punk',
#  'dance rock',
#  'funk rock',
#  'new wave',
#  'permanent wave',
#  'post-punk',
#  'rock',
#  'zolo']
# Popularity: 69
# spotify:artist:6DPYiyq5kWVQS4RGwxzPC7
# ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap']
# Popularity: 80
# spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# ['art pop', 'metropopolis', 'nz pop', 'pop']
# Popularity: 77
# spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# ['album rock', 'british invasion', 'classic rock', 'rock']
# Popularity: 79
# spotify:artist:5me0Irg2ANcsgc93uaYrpb
# ['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap']
# Popularity: 77
# spotify:artist:293zczrfYafIItmnmM3coR
# ['blues',
#  'blues rock',
#  'classic rock',
#  'rock',
#  'rock-and-roll',
#  'rockabilly',
#  'soul']
# Popularity: 66
# spotify:artist:7GaxyUddsPok8BuhxN6OUW
# ['funk', 'motown', 'soul', 'vocal jazz']
# Popularity: 62
# spotify:artist:4F84IBURUo98rz4r61KF70
# ['alternative rock',
#  'blues rock',
#  'detroit rock',
#  'garage rock',
#  'modern blues rock',
#  'permanent wave',
#  'punk blues',
#  'rock']
# Popularity: 72
# spotify:artist:5a2EaR3hamoenG9rDuVn8j
# ['funk', 'funk rock', 'minneapolis sound', 'rock', 'synth funk']
# Popularity: 71
# spotify:artist:60df5JBRRPcnSpsIMxxwQm
# ['classic soul',
#  'memphis soul',
#  'soul',
#  'soul blues',
#  'southern soul',
#  'vocal jazz']
# Popularity: 71
# spotify:artist:1G9G7WwrXka3Z1r7aIDjI7
# ['atl hip hop',
#  'dirty south rap',
#  'hip hop',
#  'old school atlanta hip hop',
#  'rap',
#  'southern hip hop']
# Popularity: 76
# spotify:artist:776Uo845nYHJpNaStv1Ds4
# ['acid rock',
#  'album rock',
#  'alternative rock',
#  'classic rock',
#  'hard rock',
#  'proto-metal',
#  'psychedelic rock',
#  'rock']
# Popularity: 69
# spotify:artist:432R46LaYsJZV2Gmc4jUV5
# ['alternative rock',
#  'indie rock',
#  'madchester',
#  'new wave',
#  'post-punk',
#  'punk',
#  'rock',
#  'uk post-punk']
# Popularity: 63
# spotify:artist:2QsynagSdAqZj3U9HgDzjD
# ['reggae', 'roots reggae']
# Popularity: 82
# spotify:artist:3RwQ26hR2tJtA8F9p2n7jG
# ['classic soul', 'disco', 'memphis soul', 'motown', 'soul']
# Popularity: 68
# spotify:artist:3fMbdgg4jU18AjLCKBhRSm
# ['r&b', 'soul']
# Popularity: 83
# spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg
# ['conscious hip hop', 'hip hop', 'rap', 'west coast rap']
# Popularity: 92
# spotify:artist:0QJIPDAEDILuo8AIq3pMuU
# ['escape room', 'indietronica', 'new rave']
# Popularity: 67
# spotify:artist:3PhoLpVuITZKcymswpck5b
# ['glam rock', 'mellow gold', 'piano rock', 'rock']
# Popularity: 83
# spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# ['alternative rock',
#  'art rock',
#  'melancholia',
#  'oxford indie',
#  'permanent wave',
#  'rock']
# Popularity: 81
# spotify:artist:2Mu5NfyYm8n5iTomuKAEHl
# ['alternative r&b',
#  'conscious hip hop',
#  'hip hop',
#  'neo soul',
#  'new jersey rap',
#  'r&b']
# Popularity: 73
# spotify:artist:4VMYDCV2IEDYJArk749S6m
# ['latin hip hop', 'reggaeton', 'trap latino', 'urbano latino']
# Popularity: 86
# spotify:artist:2JSjCHK79gdaiPWdKiNUNp
# ['adult standards',
#  'brill building pop',
#  'disco',
#  'quiet storm',
#  'soft rock',
#  'soul',
#  'vocal jazz']
# Popularity: 61
# spotify:artist:2eogQKWWoohI3BSnoG7E2U
# ['disco', 'hi-nrg', 'new wave pop', 'soft rock']
# Popularity: 63
# spotify:artist:3oDbviiivRWhXwIE8hxkVV
# ['baroque pop',
#  'classic rock',
#  'folk rock',
#  'mellow gold',
#  'psychedelic rock',
#  'rock',
#  'singer-songwriter',
#  'sunshine pop']
# Popularity: 73
# spotify:artist:6TKOZZDd5uV5KnyC5G4MUt
# ['classic soul', 'disco', 'motown', 'quiet storm', 'soul']
# Popularity: 56
# spotify:artist:6tbjWDEIzxoDsBA1FuhfPW
# ['dance pop', 'pop']
# Popularity: 80
# spotify:artist:2wIVse2owClT7go1WT98tk
# ['dance pop',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'pop rap',
#  'r&b',
#  'rap',
#  'urban contemporary',
#  'virginia hip hop']
# Popularity: 71
# spotify:artist:5m8H6zSadhu1j9Yi04VLqD
# ['classic soul',
#  'funk',
#  'funk rock',
#  'p funk',
#  'psychedelic soul',
#  'soul',
#  'southern soul']
# Popularity: 57
# spotify:artist:4vpDg7Y7fU982Ds30zawDA
# ['blues rock',
#  'classic canadian rock',
#  'classic rock',
#  'cosmic american',
#  'country rock',
#  'folk',
#  'folk rock',
#  'heartland rock',
#  'jam band',
#  'mellow gold',
#  'rock',
#  'roots rock',
#  'southern rock',
#  'swamp rock']
# Popularity: 61
# spotify:artist:1teSGKe5F5NYYeuxtL65GQ
# []
# Popularity: 5
# spotify:artist:1aSxMhuvixZ8h9dK9jIDwL
# ['art pop',
#  'art rock',
#  'baroque pop',
#  'new wave pop',
#  'permanent wave',
#  'piano rock',
#  'singer-songwriter']
# Popularity: 71
# spotify:artist:36QJpDe2go2KgaRleHCDTp
# ['album rock', 'classic rock', 'hard rock', 'rock']
# Popularity: 76
# spotify:artist:51Blml2LZPmy7TTiAg47vQ
# ['irish rock', 'permanent wave', 'rock']
# Popularity: 77
# spotify:artist:32vWCbZh0xZ4o9gkz4PsEU
# ['classic country pop', 'country', 'country dawn']
# Popularity: 75
# spotify:artist:1co4F2pPNH8JjTutZkmgSm
# ['alternative rock', 'early us punk', 'permanent wave', 'punk', 'rock']
# Popularity: 66
# spotify:artist:4QQgXkCYTt3BlENzhyNETg
# ['disco', 'funk', 'jazz funk', 'motown', 'soul']
# Popularity: 75
# spotify:artist:70cRZdQywnSFp9pnc2WTCE
# ['classic rock',
#  'folk',
#  'folk rock',
#  'melancholia',
#  'mellow gold',
#  'rock',
#  'soft rock']
# Popularity: 73
# spotify:artist:74ASZWbe4lXaubB36ztrGX
# ['classic rock',
#  'country rock',
#  'folk',
#  'folk rock',
#  'rock',
#  'roots rock',
#  'singer-songwriter']
# Popularity: 73
# spotify:artist:3iDD7bnsjL9J4fO298r0L0
# ['album rock', 'classic rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']
# Popularity: 70
# spotify:artist:06HL4z0CvFAxyc27GXpf02
# ['pop']
# Popularity: 100
# spotify:artist:43ZHCT0cAZBISjO8DG9PnE
# ['rock-and-roll', 'rockabilly']
# Popularity: 78
# spotify:artist:7oPgCQqMMXEXrNau5vxYZP
# ['folk', 'lilith', 'singer-songwriter', "women's music"]
# Popularity: 71
# spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# ['british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# Popularity: 85
# spotify:artist:6vWDO969PvNqNYHIOW5v0m
# ['pop', 'r&b']
# Popularity: 86
# spotify:artist:5l8VQNuIg0turYE1VtM9zV
# ['canadian singer-songwriter',
#  'melancholia',
#  'permanent wave',
#  'singer-songwriter']
# Popularity: 64
# spotify:artist:36E7oYfz3LLRto6l2WmDcD
# ['alternative rock', 'britpop', 'permanent wave', 'sheffield indie']
# Popularity: 59
# spotify:artist:2eRdPaLHWAL4d1WcNUO9Vz
# ['alternative rock',
#  'boston rock',
#  'experimental rock',
#  'garage rock',
#  'lo-fi',
#  'no wave']
# Popularity: 43
# spotify:artist:7fIvjotigTGWqjIz6EP1i4
# ['classic soul', 'disco', 'motown', 'quiet storm', 'soul']
# Popularity: 64
# spotify:artist:6Q192DXotxtaysaqNPy5yR
# ['british soul', 'neo soul']
# Popularity: 78
# spotify:artist:1nJvji2KIlWSseXRSlNYsC
# ['alternative rock', 'melancholia', 'permanent wave', 'protopunk', 'rock']
# Popularity: 62
# spotify:artist:4dpARuHxo51G3z768sgnrY
# ['british soul', 'pop', 'pop soul', 'uk pop']
# Popularity: 86
# spotify:artist:74ASZWbe4lXaubB36ztrGX
# ['classic rock',
#  'country rock',
#  'folk',
#  'folk rock',
#  'rock',
#  'roots rock',
#  'singer-songwriter']
# Popularity: 73
# spotify:artist:3dkbV4qihUeMsqN4vBGg93
# ['classic soul',
#  'funk',
#  'memphis soul',
#  'quiet storm',
#  'soul',
#  'soul blues',
#  'southern soul']
# Popularity: 65
# spotify:artist:5a2EaR3hamoenG9rDuVn8j
# ['funk', 'funk rock', 'minneapolis sound', 'rock', 'synth funk']
# Popularity: 71
# spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# ['album rock', 'british invasion', 'classic rock', 'rock']
# Popularity: 79
# spotify:artist:066X20Nz7iquqkkCW6Jxy6
# ['alternative dance',
#  'alternative rock',
#  'art pop',
#  'dance rock',
#  'dance-punk',
#  'electronic rock',
#  'electronica',
#  'indie rock',
#  'indietronica',
#  'neo-synthpop',
#  'new rave']
# Popularity: 60
# spotify:artist:3qm84nBOXUEQ2vnTfUTTFC
# ['glam metal', 'hard rock', 'rock']
# Popularity: 80
# spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# ['british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# Popularity: 85
# spotify:artist:7nwUJBm0HE4ZxD3f5cy5ok
# ['classic soul',
#  'jazz blues',
#  'memphis soul',
#  'soul',
#  'southern soul',
#  'vocal jazz']
# Popularity: 72
# spotify:artist:6ZhjJOJXXwnPS8PrXdmjLw
# ['dirty south rap']
# Popularity: 60
# spotify:artist:4xls23Ye9WR9yy3yYMpAMm
# ['blues', 'rock-and-roll', 'rockabilly', 'soul']
# Popularity: 58
# spotify:artist:3BmGtnKgCSGYIUhmivXKWX
# ['dance pop', 'pop', 'talent show']
# Popularity: 73
# spotify:artist:6XpaIBNiVzIetEPCWDvAFP
# ['dance pop', 'pop']
# Popularity: 76
# spotify:artist:2DaxqgrOhkeH0fpeiQq2f4
# ['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock']
# Popularity: 77
# spotify:artist:3nFkdlSjzX9mRTtwJOzDYB
# ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap']
# Popularity: 83
# spotify:artist:0vYkHhJ48Bs3jWcvZXvOrP
# ['art punk', 'permanent wave', 'protopunk', 'singer-songwriter']
# Popularity: 56
# spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# ['british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# Popularity: 85
# spotify:artist:1LZEQNv7sE11VDY3SdxQeN
# ['disco', 'mellow gold', 'soft rock']
# Popularity: 77
# spotify:artist:74ASZWbe4lXaubB36ztrGX
# ['classic rock',
#  'country rock',
#  'folk',
#  'folk rock',
#  'rock',
#  'roots rock',
#  'singer-songwriter']
# Popularity: 73
#    Rank           Artist                     Song  Released     Decade  \
# 0     1  Aretha Franklin                  Respect      1967  1960-1969
# 1     2     Public Enemy          Fight the Power      1989  1980-1989
# 2     3        Sam Cooke   A Change Is Gonna Come      1964  1960-1969
# 3     4        Bob Dylan     Like a Rolling Stone      1965  1960-1969
# 4     5          Nirvana  Smells Like Teen Spirit      1991  1990-1999
#
#                 Artist ID                                             Genres  \
# 0  7nwUJBm0HE4ZxD3f5cy5ok  classic soul, jazz blues, memphis soul, soul, ...
# 1  6Mo9PoU6svvhgEum7wh2Nd  conscious hip hop, east coast hip hop, golden ...
# 2  6hnWRPzGGKiapVX1UCdEAC                     classic soul, soul, vocal jazz
# 3  74ASZWbe4lXaubB36ztrGX  classic rock, country rock, folk, folk rock, r...
# 4  6olE6TJLqED3rqDCT0FyPh                       grunge, permanent wave, rock
#
#   Popularity
# 0         72
# 1         56
# 2         68
# 3         73
# 4         82

# %%
sorted_500_df = genre_500_df.sort_values(by='Popularity', ascending=False)
most_popular_song = sorted_500_df.iloc[0]['Song']
most_popular_artist = sorted_500_df.iloc[0]['Artist']
print(f'The most popular song based on Popularity score is {most_popular_song} by {most_popular_artist}.')
sorted_500_df.head()
# Out:
# The most popular song based on Popularity score is All Too Well by Taylor Swift.
#     Rank          Artist                 Song  Released     Decade  \
# 66    69    Taylor Swift         All Too Well      2012  2010-2024
# 23    25      Kanye West              Runaway      2010  2010-2024
# 42    45  Kendrick Lamar              Alright      2015  2010-2024
# 70    73         Beyoncé            Formation      2016  2010-2024
# 77    82           Adele  Rolling in the Deep      2011  2010-2024
#
#                  Artist ID                                           Genres  \
# 66  06HL4z0CvFAxyc27GXpf02                                              pop
# 23  5K4W6rqBFWDnAN6FQUkS6x                        chicago rap, hip hop, rap
# 42  2YZyLoL8N0Wb9xBt1NhZWg  conscious hip hop, hip hop, rap, west coast rap
# 70  6vWDO969PvNqNYHIOW5v0m                                         pop, r&b
# 77  4dpARuHxo51G3z768sgnrY              british soul, pop, pop soul, uk pop
#
#    Popularity
# 66        100
# 23         92
# 42         92
# 70         86
# 77         86

# %%
#count the total genres listed for each row
count_genre_500_df = pd.DataFrame(genre_500_df)

#split the genre into seperate entries 
genre_500_series = count_genre_500_df['Genres'].str.split(', ', expand=True).stack()

#new DF
count_genre_500_df = pd.DataFrame(genre_500_series, columns=['Genre'])

#Count the occurances
genre_500_count = count_genre_500_df['Genre'].value_counts()

#convert to new DF 
final_count_500_df = genre_500_count.reset_index()
final_count_500_df.columns = ['Genre', 'Count']

print(final_count_500_df)
# Out:
#                  Genre  Count
# 0                 rock     41
# 1         classic rock     26
# 2                 soul     17
# 3       permanent wave     14
# 4    singer-songwriter     13
# ..                 ...    ...
# 137      latin hip hop      1
# 138          reggaeton      1
# 139        trap latino      1
# 140      urbano latino      1
# 141         beatlesque      1
#
# [142 rows x 2 columns]

# %%
top_10_genres_500 = final_count_500_df.head(10)

plt.figure(figsize=(10, 6)) 
plt.bar(top_10_genres_500['Genre'], top_10_genres_500['Count'], color='blue')

plt.title('Top 10 Genre by Count')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show plot
plt.savefig("output_data/500_Genre_Bar.png")
plt.tight_layout()
plt.show()
